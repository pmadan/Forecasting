# %%
# %matplotlib inline

from scipy import stats
import statsmodels.api as sm
from statsmodels.graphics.api import qqplot

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

import pandas.io.data as web

pd.set_option('display.mpl_style', 'default')

plt.rcParams['figure.figsize'] = (20, 10)

# %%
spc = web.DataReader(name = "^GSPC", data_source = 'yahoo', start = '2010-1-1')
spc['Returns'] = np.log(spc['Adj Close'] / spc['Adj Close'].shift(1))    
dta = pd.DataFrame(spc["Returns"])
dta = dta.dropna()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(dta.values.squeeze(), lags=30, ax=ax1)    # ?squeeze verify ACF for SP50
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(dta, lags=30, ax=ax2)

# %%
#arma_mod20 = sm.tsa.ARMA(dta, (2,0)).fit()
#print(arma_mod20.params)
#print(arma_mod20.aic, arma_mod20.bic, arma_mod20.hqic)
# LinAlgError: SVD did not converge

# %%
arma_mod30 = sm.tsa.ARMA(dta, (3, 0)).fit()
print "Parameters: ", (arma_mod30.params)
print "AIC: ", arma_mod30.aic, "BIC: ",  arma_mod30.bic, "HQIC: ", arma_mod30.hqic
print "Durbin Watson score: ", sm.stats.durbin_watson(arma_mod30.resid.values)
# Out:
# Parameters:  const            0.000479
# ar.L1.Returns   -0.062629
# ar.L2.Returns    0.040476
# ar.L3.Returns   -0.067946
# dtype: float64
# AIC:  -7784.58013513 BIC:  -7759.02257454 HQIC:  -7774.96298617
# Durbin Watson score:  1.99828466568

# %%
#arma_mod30.resid.plot()
resid = arma_mod30.resid
print stats.normaltest(resid)
fig = qqplot(resid, line = 'q', fit = True)
# Out:
# (174.14474168378743, 1.5309105542510089e-38)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(resid.values.squeeze(), lags = 40, ax = ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(resid, lags = 40, ax = ax2)

# %%
r, q, p = sm.tsa.acf(resid.values.squeeze(), qstat = True)
data = np.c_[range(1,41), r[1:], q, p]
table = pd.DataFrame(data, columns = ['lag', "AC", "Q", "Prob(>Q)"])
print(table.set_index('lag'))
# Out:
#            AC          Q  Prob(>Q)
# lag
# 1    0.000830   0.000846  0.976795
# 2   -0.007517   0.070352  0.965435
# 3    0.004242   0.092509  0.992721
# 4    0.007067   0.154046  0.997182
# 5   -0.105370  13.844188  0.016630
# 6   -0.009432  13.953977  0.030155
# 7    0.010603  14.092834  0.049555
# 8   -0.011768  14.264018  0.075138
# 9   -0.017907  14.660686  0.100688
# 10   0.059547  19.050779  0.039622
# 11   0.020200  19.556379  0.051809
# 12  -0.006302  19.605625  0.074924
# 13  -0.005190  19.639062  0.104583
# 14  -0.043506  21.990220  0.078816
# 15  -0.028582  23.005868  0.084015
# 16   0.015409  23.301297  0.105914
# 17   0.032864  24.646222  0.102913
# 18  -0.067948  30.400219  0.033733
# 19  -0.041658  32.564859  0.026969
# 20   0.032345  33.870903  0.027011
# 21  -0.032983  35.230104  0.026636
# 22  -0.062603  40.130677  0.010438
# 23   0.037935  41.931679  0.009246
# 24   0.032385  43.245312  0.009325
# 25  -0.111525  58.837003  0.000151
# 26  -0.035137  60.385977  0.000149
# 27   0.042340  62.637008  0.000118
# 28   0.025990  63.485888  0.000143
# 29   0.027820  64.459347  0.000167
# 30   0.023349  65.145589  0.000210
# 31  -0.018992  65.600015  0.000281
# 32  -0.050237  68.782189  0.000169
# 33  -0.010005  68.908510  0.000247
# 34   0.000250  68.908589  0.000368
# 35  -0.021551  69.495664  0.000461
# 36   0.015763  69.810010  0.000616
# 37   0.052684  73.324462  0.000347
# 38   0.022862  73.986815  0.000422
# 39   0.058849  78.379288  0.000187
# 40   0.037981  80.210447  0.000166

# %%
def mean_forecast_err(y, yhat):
    return y.sub(yhat).mean() 

ranges = [('2010-02', '2011-02', 'r--'), ('2012-04', '2013-01', 'm--'), ('2013-04', '2014-01', 'k--'),('2014-01', '2014-07', 'g--')]
mean_err = []

ax = dta.plot(title = 'Dynamic Prediction')
for r in ranges:
    output = arma_mod30.predict(r[0], r[1], dynamic = True)
    ax = output.plot(ax = ax, style = r[2], linewidth = 3)
    mean_err.append(mean_forecast_err(dta["Returns"], output))
plt.show()

print "Mean forecast error for different time ranges"
for i in range(len(mean_err)):
    r = ranges[i]
    print "Period: ", r[0], " - ", r[1], " : ", mean_err[i]
# Out:
# Mean forecast error for different time ranges
# Period:  2010-02  -  2011-02  :  0.00032177320906
# Period:  2012-04  -  2013-01  :  -6.56702196218e-05
# Period:  2013-04  -  2014-01  :  0.00033008827537
# Period:  2014-01  -  2014-07  :  -2.27461334431e-06

# %%
# Test the ARIMA model. Establish stationarity

# %%
print(sm.tsa.stattools.adfuller(dta["Returns"]))
# Out:
# (-17.735427476879551, 3.4203857876941327e-30, 4, 1221, {'5%': -2.8639100200710828, '1%': -3.435716995109265, '10%': -2.568031835031368}, -7653.7539138170505)
